# %%
import numpy as np

# %%
input_data = np.array([[0,0],[0,1],[1,0],[1,1]])
target_data = np.array([0,1,1,0])

# %%
# weight initilization function
def weight_initilization(nodes, input_dimension):
    w = np.random.normal(0, 1,size = (nodes,input_dimension))
    return w

# %%
# bias initilization
def bias_initilization(nodes):
    b = np.random.normal(size = (nodes,1))
    #b = np.ones((1, nodes))
    return b

# %%
def sigmoid(z):
    s = 1/(1+np.exp(-z))
    return s

# %%
def derivative_of_sigmoid(z):
    s = sigmoid(z)*(1-sigmoid(z))
    return s

# %%
def mse_loss(desired_output, predicted_output):
  # desired_output and predicted_output are numpy arrays of the same length.
  return ((desired_output - predicted_output) ** 2).mean()

# %%
# FORWARD PROP
def forward_prop(first_layer_weights, first_layer_bias, second_layer_weights, second_layer_bias, input_data):

    # First hidden layer
    first_layer_weighted_sum = first_layer_weights.dot(input_data) + first_layer_bias
    first_layer_output = sigmoid(first_layer_weighted_sum)

    # 2nd layer (output layer)
    second_layer_weighted_sum = second_layer_weights.dot(first_layer_output) + second_layer_bias
    second_layer_output = sigmoid(second_layer_weighted_sum)
    
    return first_layer_output, second_layer_output, first_layer_weighted_sum, second_layer_weighted_sum

# %%
# BACKPROP
def backprop(first_layer_output ,second_layer_output, first_layer_weights, second_layer_weights,
             first_layer_weighted_sum, second_layer_weighted_sum, input_data, target_data):
   
    m = input_data.shape[1]
    
    # Compute derivatives for second (output) layer
    dZ2 = second_layer_output - target_data
    second_layer_delta_weight = (1/m) * dZ2.dot(first_layer_output.T)
    second_layer_delta_bias = (1/m) * np.sum(dZ2, axis=1, keepdims=True)

    # Computer derivatives for first layer
    dZ1 = second_layer_weights.T.dot(dZ2) * derivative_of_sigmoid(first_layer_weighted_sum)
    first_layer_delta_weight = (1/m) * dZ1.dot(input_data.T)
    first_layer_delta_bias = (1/m) * np.sum(dZ1, axis=1, keepdims=True)
    
    return first_layer_delta_weight, second_layer_delta_weight, first_layer_delta_bias, second_layer_delta_bias

# %%
def train(input_data, target_data, lr=0.001, n_iter=1000, display_training=True):
    nodes = 2
    
    # Initialize the first layer
    W1 = weight_initilization(nodes,input_data.shape[0])
    b1 = bias_initilization(nodes)

    # Initialize the second layer
    W2 = weight_initilization(1, nodes)
    b2 = bias_initilization(1)

    # Run for n_iter iterations
    for n in range(1, n_iter+1):
        print(f"Iteration: {n}")
        print("Old weights:")
        print(f"weights of first layer: {W1}.\t weights of second layer: {W2}")
        A1, A2, Z1, Z2 = forward_prop(W1, b1, W2, b2, input_data)
        dW1, dW2, db1, db2 = backprop(A1, A2, W1, W2, Z1, Z2, input_data, target_data)

        # Update all the layers
        W1 = W1 - lr * dW1
        W2 = W2 - lr * dW2
        b1 = b1 - lr * db1
        b2 = b2 - lr * db2
        print("New weights:")
        print(f"weights of first layer: {W1}.\t weights of second layer: {W2}")
        print('\n\n\n')

    return W1, W2, b1, b2

# %%
W1, W2, b1, b2 = train(input_data.T, target_data, n_iter=1000)
# Out:
# Iteration: 1
# Old weights:
# weights of first layer: [[-0.71733463  1.4457609 ]
#  [-2.70186847 -0.58112653]].	 weights of second layer: [[-1.51428253 -1.54208096]]
# New weights:
# weights of first layer: [[-0.71732346  1.44571978]
#  [-2.70187331 -0.58117817]].	 weights of second layer: [[-1.5142171  -1.54205789]]
#
#
#
#
# Iteration: 2
# Old weights:
# weights of first layer: [[-0.71732346  1.44571978]
#  [-2.70187331 -0.58117817]].	 weights of second layer: [[-1.5142171  -1.54205789]]
# New weights:
# weights of first layer: [[-0.71731229  1.44567868]
#  [-2.70187816 -0.58122981]].	 weights of second layer: [[-1.51415169 -1.54203483]]
#
#
#
#
# Iteration: 3
# Old weights:
# weights of first layer: [[-0.71731229  1.44567868]
#  [-2.70187816 -0.58122981]].	 weights of second layer: [[-1.51415169 -1.54203483]]
# New weights:
# weights of first layer: [[-0.71730111  1.44563758]
#  [-2.701883   -0.58128144]].	 weights of second layer: [[-1.51408629 -1.54201177]]
#
#
#
#
# Iteration: 4
# Old weights:
# weights of first layer: [[-0.71730111  1.44563758]
#  [-2.701883   -0.58128144]].	 weights of second layer: [[-1.51408629 -1.54201177]]
# New weights:
# weights of first layer: [[-0.71728993  1.4455965 ]
#  [-2.70188784 -0.58133306]].	 weights of second layer: [[-1.51402091 -1.54198873]]
#
#
#
#
# Iteration: 5
# Old weights:
# weights of first layer: [[-0.71728993  1.4455965 ]
#  [-2.70188784 -0.58133306]].	 weights of second layer: [[-1.51402091 -1.54198873]]
# New weights:
# weights of first layer: [[-0.71727875  1.44555542]
#  [-2.70189268 -0.58138467]].	 weights of second layer: [[-1.51395555 -1.5419657 ]]
#
#
#
#
# Iteration: 6
# Old weights:
# weights of first layer: [[-0.71727875  1.44555542]
#  [-2.70189268 -0.58138467]].	 weights of second layer: [[-1.51395555 -1.5419657 ]]
# New weights:
# weights of first layer: [[-0.71726756  1.44551435]
#  [-2.70189752 -0.58143628]].	 weights of second layer: [[-1.5138902  -1.54194268]]
#
#
#
#
# Iteration: 7
# Old weights:
# weights of first layer: [[-0.71726756  1.44551435]
#  [-2.70189752 -0.58143628]].	 weights of second layer: [[-1.5138902  -1.54194268]]
# New weights:
# weights of first layer: [[-0.71725636  1.4454733 ]
#  [-2.70190236 -0.58148789]].	 weights of second layer: [[-1.51382487 -1.54191967]]
#
#
#
#
# Iteration: 8
# Old weights:
# weights of first layer: [[-0.71725636  1.4454733 ]
#  [-2.70190236 -0.58148789]].	 weights of second layer: [[-1.51382487 -1.54191967]]
# New weights:
# weights of first layer: [[-0.71724516  1.44543225]
#  [-2.70190719 -0.58153948]].	 weights of second layer: [[-1.51375955 -1.54189667]]
#
#
#
#
# Iteration: 9
# Old weights:
# weights of first layer: [[-0.71724516  1.44543225]
#  [-2.70190719 -0.58153948]].	 weights of second layer: [[-1.51375955 -1.54189667]]
# New weights:
# weights of first layer: [[-0.71723396  1.44539121]
#  [-2.70191203 -0.58159107]].	 weights of second layer: [[-1.51369425 -1.54187368]]
#
#
#
#
# Iteration: 10
# Old weights:
# weights of first layer: [[-0.71723396  1.44539121]
#  [-2.70191203 -0.58159107]].	 weights of second layer: [[-1.51369425 -1.54187368]]
# New weights:
# weights of first layer: [[-0.71722275  1.44535018]
#  [-2.70191686 -0.58164265]].	 weights of second layer: [[-1.51362896 -1.54185069]]
#
#
#
#
# Iteration: 11
# Old weights:
# weights of first layer: [[-0.71722275  1.44535018]
#  [-2.70191686 -0.58164265]].	 weights of second layer: [[-1.51362896 -1.54185069]]
# New weights:
# weights of first layer: [[-0.71721153  1.44530916]
#  [-2.70192169 -0.58169423]].	 weights of second layer: [[-1.51356369 -1.54182772]]
#
#
#
#
# Iteration: 12
# Old weights:
# weights of first layer: [[-0.71721153  1.44530916]
#  [-2.70192169 -0.58169423]].	 weights of second layer: [[-1.51356369 -1.54182772]]
# New weights:
# weights of first layer: [[-0.71720031  1.44526815]
#  [-2.70192653 -0.5817458 ]].	 weights of second layer: [[-1.51349843 -1.54180476]]
#
#
#
#
# Iteration: 13
# Old weights:
# weights of first layer: [[-0.71720031  1.44526815]
#  [-2.70192653 -0.5817458 ]].	 weights of second layer: [[-1.51349843 -1.54180476]]
# New weights:
# weights of first layer: [[-0.71718909  1.44522715]
#  [-2.70193136 -0.58179736]].	 weights of second layer: [[-1.51343319 -1.54178181]]
#
#
#
#
# Iteration: 14
# Old weights:
# weights of first layer: [[-0.71718909  1.44522715]
#  [-2.70193136 -0.58179736]].	 weights of second layer: [[-1.51343319 -1.54178181]]
# New weights:
# weights of first layer: [[-0.71717786  1.44518616]
#  [-2.70193619 -0.58184892]].	 weights of second layer: [[-1.51336797 -1.54175887]]
#
#
#
#
# Iteration: 15
# Old weights:
# weights of first layer: [[-0.71717786  1.44518616]
#  [-2.70193619 -0.58184892]].	 weights of second layer: [[-1.51336797 -1.54175887]]
# New weights:
# weights of first layer: [[-0.71716662  1.44514518]
#  [-2.70194102 -0.58190047]].	 weights of second layer: [[-1.51330276 -1.54173594]]
#
#
#
#
# Iteration: 16
# Old weights:
# weights of first layer: [[-0.71716662  1.44514518]
#  [-2.70194102 -0.58190047]].	 weights of second layer: [[-1.51330276 -1.54173594]]
# New weights:
# weights of first layer: [[-0.71715538  1.44510421]
#  [-2.70194584 -0.58195201]].	 weights of second layer: [[-1.51323757 -1.54171302]]
#
#
#
#
# Iteration: 17
# Old weights:
# weights of first layer: [[-0.71715538  1.44510421]
#  [-2.70194584 -0.58195201]].	 weights of second layer: [[-1.51323757 -1.54171302]]
# New weights:
# weights of first layer: [[-0.71714414  1.44506325]
#  [-2.70195067 -0.58200355]].	 weights of second layer: [[-1.51317239 -1.54169011]]
#
#
#
#
# Iteration: 18
# Old weights:
# weights of first layer: [[-0.71714414  1.44506325]
#  [-2.70195067 -0.58200355]].	 weights of second layer: [[-1.51317239 -1.54169011]]
# New weights:
# weights of first layer: [[-0.71713289  1.4450223 ]
#  [-2.7019555  -0.58205508]].	 weights of second layer: [[-1.51310723 -1.5416672 ]]
#
#
#
#
# Iteration: 19
# Old weights:
# weights of first layer: [[-0.71713289  1.4450223 ]
#  [-2.7019555  -0.58205508]].	 weights of second layer: [[-1.51310723 -1.5416672 ]]
# New weights:
# weights of first layer: [[-0.71712163  1.44498135]
#  [-2.70196032 -0.5821066 ]].	 weights of second layer: [[-1.51304208 -1.54164431]]
#
#
#
#
# Iteration: 20
# Old weights:
# weights of first layer: [[-0.71712163  1.44498135]
#  [-2.70196032 -0.5821066 ]].	 weights of second layer: [[-1.51304208 -1.54164431]]
# New weights:
# weights of first layer: [[-0.71711037  1.44494042]
#  [-2.70196514 -0.58215812]].	 weights of second layer: [[-1.51297695 -1.54162143]]
#
#
#
#
# Iteration: 21
# Old weights:
# weights of first layer: [[-0.71711037  1.44494042]
#  [-2.70196514 -0.58215812]].	 weights of second layer: [[-1.51297695 -1.54162143]]
# New weights:
# weights of first layer: [[-0.71709911  1.4448995 ]
#  [-2.70196997 -0.58220963]].	 weights of second layer: [[-1.51291184 -1.54159856]]
#
#
#
#
# Iteration: 22
# Old weights:
# weights of first layer: [[-0.71709911  1.4448995 ]
#  [-2.70196997 -0.58220963]].	 weights of second layer: [[-1.51291184 -1.54159856]]
# New weights:
# weights of first layer: [[-0.71708784  1.44485858]
#  [-2.70197479 -0.58226113]].	 weights of second layer: [[-1.51284674 -1.5415757 ]]
#
#
#
#
# Iteration: 23
# Old weights:
# weights of first layer: [[-0.71708784  1.44485858]
#  [-2.70197479 -0.58226113]].	 weights of second layer: [[-1.51284674 -1.5415757 ]]
# New weights:
# weights of first layer: [[-0.71707657  1.44481768]
#  [-2.70197961 -0.58231263]].	 weights of second layer: [[-1.51278166 -1.54155285]]
#
#
#
#
# Iteration: 24
# Old weights:
# weights of first layer: [[-0.71707657  1.44481768]
#  [-2.70197961 -0.58231263]].	 weights of second layer: [[-1.51278166 -1.54155285]]
# New weights:
# weights of first layer: [[-0.71706529  1.44477678]
#  [-2.70198442 -0.58236412]].	 weights of second layer: [[-1.51271659 -1.54153001]]
#
#
#
#
# Iteration: 25
# Old weights:
# weights of first layer: [[-0.71706529  1.44477678]
#  [-2.70198442 -0.58236412]].	 weights of second layer: [[-1.51271659 -1.54153001]]
# New weights:
# weights of first layer: [[-0.717054    1.4447359 ]
#  [-2.70198924 -0.58241561]].	 weights of second layer: [[-1.51265153 -1.54150717]]
#
#
#
#
# Iteration: 26
# Old weights:
# weights of first layer: [[-0.717054    1.4447359 ]
#  [-2.70198924 -0.58241561]].	 weights of second layer: [[-1.51265153 -1.54150717]]
# New weights:
# weights of first layer: [[-0.71704272  1.44469502]
#  [-2.70199406 -0.58246708]].	 weights of second layer: [[-1.5125865  -1.54148435]]
#
#
#
#
# Iteration: 27
# Old weights:
# weights of first layer: [[-0.71704272  1.44469502]
#  [-2.70199406 -0.58246708]].	 weights of second layer: [[-1.5125865  -1.54148435]]
# New weights:
# weights of first layer: [[-0.71703142  1.44465416]
#  [-2.70199887 -0.58251855]].	 weights of second layer: [[-1.51252148 -1.54146154]]
#
#
#
#
# Iteration: 28
# Old weights:
# weights of first layer: [[-0.71703142  1.44465416]
#  [-2.70199887 -0.58251855]].	 weights of second layer: [[-1.51252148 -1.54146154]]
# New weights:
# weights of first layer: [[-0.71702012  1.4446133 ]
#  [-2.70200369 -0.58257002]].	 weights of second layer: [[-1.51245647 -1.54143874]]
#
#
#
#
# Iteration: 29
# Old weights:
# weights of first layer: [[-0.71702012  1.4446133 ]
#  [-2.70200369 -0.58257002]].	 weights of second layer: [[-1.51245647 -1.54143874]]
# New weights:
# weights of first layer: [[-0.71700882  1.44457245]
#  [-2.7020085  -0.58262147]].	 weights of second layer: [[-1.51239148 -1.54141595]]
#
#
#
#
# Iteration: 30
# Old weights:
# weights of first layer: [[-0.71700882  1.44457245]
#  [-2.7020085  -0.58262147]].	 weights of second layer: [[-1.51239148 -1.54141595]]
# New weights:
# weights of first layer: [[-0.71699751  1.44453162]
#  [-2.70201331 -0.58267293]].	 weights of second layer: [[-1.5123265  -1.54139317]]
#
#
#
#
# Iteration: 31
# Old weights:
# weights of first layer: [[-0.71699751  1.44453162]
#  [-2.70201331 -0.58267293]].	 weights of second layer: [[-1.5123265  -1.54139317]]
# New weights:
# weights of first layer: [[-0.7169862   1.44449079]
#  [-2.70201813 -0.58272437]].	 weights of second layer: [[-1.51226155 -1.5413704 ]]
#
#
#
#
# Iteration: 32
# Old weights:
# weights of first layer: [[-0.7169862   1.44449079]
#  [-2.70201813 -0.58272437]].	 weights of second layer: [[-1.51226155 -1.5413704 ]]
# New weights:
# weights of first layer: [[-0.71697488  1.44444997]
#  [-2.70202294 -0.58277581]].	 weights of second layer: [[-1.5121966  -1.54134763]]
#
#
#
#
# Iteration: 33
# Old weights:
# weights of first layer: [[-0.71697488  1.44444997]
#  [-2.70202294 -0.58277581]].	 weights of second layer: [[-1.5121966  -1.54134763]]
# New weights:
# weights of first layer: [[-0.71696356  1.44440916]
#  [-2.70202774 -0.58282724]].	 weights of second layer: [[-1.51213167 -1.54132488]]
#
#
#
#
# Iteration: 34
# Old weights:
# weights of first layer: [[-0.71696356  1.44440916]
#  [-2.70202774 -0.58282724]].	 weights of second layer: [[-1.51213167 -1.54132488]]
# New weights:
# weights of first layer: [[-0.71695223  1.44436836]
#  [-2.70203255 -0.58287866]].	 weights of second layer: [[-1.51206676 -1.54130214]]
#
#
#
#
# Iteration: 35
# Old weights:
# weights of first layer: [[-0.71695223  1.44436836]
#  [-2.70203255 -0.58287866]].	 weights of second layer: [[-1.51206676 -1.54130214]]
# New weights:
# weights of first layer: [[-0.7169409   1.44432757]
#  [-2.70203736 -0.58293008]].	 weights of second layer: [[-1.51200186 -1.54127941]]
#
#
#
#
# Iteration: 36
# Old weights:
# weights of first layer: [[-0.7169409   1.44432757]
#  [-2.70203736 -0.58293008]].	 weights of second layer: [[-1.51200186 -1.54127941]]
# New weights:
# weights of first layer: [[-0.71692956  1.44428679]
#  [-2.70204216 -0.58298149]].	 weights of second layer: [[-1.51193698 -1.54125669]]
#
#
#
#
# Iteration: 37
# Old weights:
# weights of first layer: [[-0.71692956  1.44428679]
#  [-2.70204216 -0.58298149]].	 weights of second layer: [[-1.51193698 -1.54125669]]
# New weights:
# weights of first layer: [[-0.71691822  1.44424602]
#  [-2.70204697 -0.5830329 ]].	 weights of second layer: [[-1.51187212 -1.54123398]]
#
#
#
#
# Iteration: 38
# Old weights:
# weights of first layer: [[-0.71691822  1.44424602]
#  [-2.70204697 -0.5830329 ]].	 weights of second layer: [[-1.51187212 -1.54123398]]
# New weights:
# weights of first layer: [[-0.71690687  1.44420525]
#  [-2.70205177 -0.5830843 ]].	 weights of second layer: [[-1.51180726 -1.54121127]]
#
#
#
#
# Iteration: 39
# Old weights:
# weights of first layer: [[-0.71690687  1.44420525]
#  [-2.70205177 -0.5830843 ]].	 weights of second layer: [[-1.51180726 -1.54121127]]
# New weights:
# weights of first layer: [[-0.71689552  1.4441645 ]
#  [-2.70205657 -0.58313569]].	 weights of second layer: [[-1.51174243 -1.54118858]]
#
#
#
#
# Iteration: 40
# Old weights:
# weights of first layer: [[-0.71689552  1.4441645 ]
#  [-2.70205657 -0.58313569]].	 weights of second layer: [[-1.51174243 -1.54118858]]
# New weights:
# weights of first layer: [[-0.71688416  1.44412376]
#  [-2.70206138 -0.58318707]].	 weights of second layer: [[-1.51167761 -1.5411659 ]]
#
#
#
#
# Iteration: 41
# Old weights:
# weights of first layer: [[-0.71688416  1.44412376]
#  [-2.70206138 -0.58318707]].	 weights of second layer: [[-1.51167761 -1.5411659 ]]
# New weights:
# weights of first layer: [[-0.7168728   1.44408303]
#  [-2.70206618 -0.58323845]].	 weights of second layer: [[-1.51161281 -1.54114323]]
#
#
#
#
# Iteration: 42
# Old weights:
# weights of first layer: [[-0.7168728   1.44408303]
#  [-2.70206618 -0.58323845]].	 weights of second layer: [[-1.51161281 -1.54114323]]
# New weights:
# weights of first layer: [[-0.71686143  1.4440423 ]
#  [-2.70207097 -0.58328982]].	 weights of second layer: [[-1.51154802 -1.54112057]]
#
#
#
#
# Iteration: 43
# Old weights:
# weights of first layer: [[-0.71686143  1.4440423 ]
#  [-2.70207097 -0.58328982]].	 weights of second layer: [[-1.51154802 -1.54112057]]
# New weights:
# weights of first layer: [[-0.71685006  1.44400159]
#  [-2.70207577 -0.58334119]].	 weights of second layer: [[-1.51148324 -1.54109791]]
#
#
#
#
# Iteration: 44
# Old weights:
# weights of first layer: [[-0.71685006  1.44400159]
#  [-2.70207577 -0.58334119]].	 weights of second layer: [[-1.51148324 -1.54109791]]
# New weights:
# weights of first layer: [[-0.71683868  1.44396088]
#  [-2.70208057 -0.58339255]].	 weights of second layer: [[-1.51141849 -1.54107527]]
#
#
#
#
# Iteration: 45
# Old weights:
# weights of first layer: [[-0.71683868  1.44396088]
#  [-2.70208057 -0.58339255]].	 weights of second layer: [[-1.51141849 -1.54107527]]
# New weights:
# weights of first layer: [[-0.7168273   1.44392019]
#  [-2.70208537 -0.5834439 ]].	 weights of second layer: [[-1.51135374 -1.54105264]]
#
#
#
#
# Iteration: 46
# Old weights:
# weights of first layer: [[-0.7168273   1.44392019]
#  [-2.70208537 -0.5834439 ]].	 weights of second layer: [[-1.51135374 -1.54105264]]
# New weights:
# weights of first layer: [[-0.71681592  1.4438795 ]
#  [-2.70209016 -0.58349524]].	 weights of second layer: [[-1.51128902 -1.54103002]]
#
#
#
#
# Iteration: 47
# Old weights:
# weights of first layer: [[-0.71681592  1.4438795 ]
#  [-2.70209016 -0.58349524]].	 weights of second layer: [[-1.51128902 -1.54103002]]
# New weights:
# weights of first layer: [[-0.71680453  1.44383883]
#  [-2.70209495 -0.58354658]].	 weights of second layer: [[-1.5112243 -1.5410074]]
#
#
#
#
# Iteration: 48
# Old weights:
# weights of first layer: [[-0.71680453  1.44383883]
#  [-2.70209495 -0.58354658]].	 weights of second layer: [[-1.5112243 -1.5410074]]
# New weights:
# weights of first layer: [[-0.71679313  1.44379816]
#  [-2.70209975 -0.58359792]].	 weights of second layer: [[-1.51115961 -1.5409848 ]]
#
#
#
#
# Iteration: 49
# Old weights:
# weights of first layer: [[-0.71679313  1.44379816]
#  [-2.70209975 -0.58359792]].	 weights of second layer: [[-1.51115961 -1.5409848 ]]
# New weights:
# weights of first layer: [[-0.71678173  1.4437575 ]
#  [-2.70210454 -0.58364924]].	 weights of second layer: [[-1.51109493 -1.54096221]]
#
#
#
#
# Iteration: 50
# Old weights:
# weights of first layer: [[-0.71678173  1.4437575 ]
#  [-2.70210454 -0.58364924]].	 weights of second layer: [[-1.51109493 -1.54096221]]
# New weights:
# weights of first layer: [[-0.71677032  1.44371685]
#  [-2.70210933 -0.58370056]].	 weights of second layer: [[-1.51103026 -1.54093963]]
#
#
#
#
# Iteration: 51
# Old weights:
# weights of first layer: [[-0.71677032  1.44371685]
#  [-2.70210933 -0.58370056]].	 weights of second layer: [[-1.51103026 -1.54093963]]
# New weights:
# weights of first layer: [[-0.71675891  1.44367621]
#  [-2.70211412 -0.58375187]].	 weights of second layer: [[-1.51096561 -1.54091705]]
#
#
#
#
# Iteration: 52
# Old weights:
# weights of first layer: [[-0.71675891  1.44367621]
#  [-2.70211412 -0.58375187]].	 weights of second layer: [[-1.51096561 -1.54091705]]
# New weights:
# weights of first layer: [[-0.7167475   1.44363559]
#  [-2.7021189  -0.58380318]].	 weights of second layer: [[-1.51090098 -1.54089449]]
#
#
#
#
# Iteration: 53
# Old weights:
# weights of first layer: [[-0.7167475   1.44363559]
#  [-2.7021189  -0.58380318]].	 weights of second layer: [[-1.51090098 -1.54089449]]
# New weights:
# weights of first layer: [[-0.71673608  1.44359497]
#  [-2.70212369 -0.58385448]].	 weights of second layer: [[-1.51083636 -1.54087194]]
#
#
#
#
# Iteration: 54
# Old weights:
# weights of first layer: [[-0.71673608  1.44359497]
#  [-2.70212369 -0.58385448]].	 weights of second layer: [[-1.51083636 -1.54087194]]
# New weights:
# weights of first layer: [[-0.71672465  1.44355436]
#  [-2.70212848 -0.58390577]].	 weights of second layer: [[-1.51077176 -1.54084939]]
#
#
#
#
# Iteration: 55
# Old weights:
# weights of first layer: [[-0.71672465  1.44355436]
#  [-2.70212848 -0.58390577]].	 weights of second layer: [[-1.51077176 -1.54084939]]
# New weights:
# weights of first layer: [[-0.71671322  1.44351375]
#  [-2.70213326 -0.58395706]].	 weights of second layer: [[-1.51070717 -1.54082686]]
#
#
#
#
# Iteration: 56
# Old weights:
# weights of first layer: [[-0.71671322  1.44351375]
#  [-2.70213326 -0.58395706]].	 weights of second layer: [[-1.51070717 -1.54082686]]
# New weights:
# weights of first layer: [[-0.71670179  1.44347316]
#  [-2.70213805 -0.58400834]].	 weights of second layer: [[-1.5106426  -1.54080434]]
#
#
#
#
# Iteration: 57
# Old weights:
# weights of first layer: [[-0.71670179  1.44347316]
#  [-2.70213805 -0.58400834]].	 weights of second layer: [[-1.5106426  -1.54080434]]
# New weights:
# weights of first layer: [[-0.71669035  1.44343258]
#  [-2.70214283 -0.58405962]].	 weights of second layer: [[-1.51057804 -1.54078182]]
#
#
#
#
# Iteration: 58
# Old weights:
# weights of first layer: [[-0.71669035  1.44343258]
#  [-2.70214283 -0.58405962]].	 weights of second layer: [[-1.51057804 -1.54078182]]
# New weights:
# weights of first layer: [[-0.7166789   1.44339201]
#  [-2.70214761 -0.58411088]].	 weights of second layer: [[-1.5105135  -1.54075932]]
#
#
#
#
# Iteration: 59
# Old weights:
# weights of first layer: [[-0.7166789   1.44339201]
#  [-2.70214761 -0.58411088]].	 weights of second layer: [[-1.5105135  -1.54075932]]
# New weights:
# weights of first layer: [[-0.71666745  1.44335145]
#  [-2.70215239 -0.58416214]].	 weights of second layer: [[-1.51044897 -1.54073683]]
#
#
#
#
# Iteration: 60
# Old weights:
# weights of first layer: [[-0.71666745  1.44335145]
#  [-2.70215239 -0.58416214]].	 weights of second layer: [[-1.51044897 -1.54073683]]
# New weights:
# weights of first layer: [[-0.716656    1.44331089]
#  [-2.70215717 -0.5842134 ]].	 weights of second layer: [[-1.51038446 -1.54071434]]
#
#
#
#
# Iteration: 61
# Old weights:
# weights of first layer: [[-0.716656    1.44331089]
#  [-2.70215717 -0.5842134 ]].	 weights of second layer: [[-1.51038446 -1.54071434]]
# New weights:
# weights of first layer: [[-0.71664454  1.44327035]
#  [-2.70216195 -0.58426464]].	 weights of second layer: [[-1.51031997 -1.54069187]]
#
#
#
#
# Iteration: 62
# Old weights:
# weights of first layer: [[-0.71664454  1.44327035]
#  [-2.70216195 -0.58426464]].	 weights of second layer: [[-1.51031997 -1.54069187]]
# New weights:
# weights of first layer: [[-0.71663308  1.44322981]
#  [-2.70216673 -0.58431589]].	 weights of second layer: [[-1.51025549 -1.5406694 ]]
#
#
#
#
# Iteration: 63
# Old weights:
# weights of first layer: [[-0.71663308  1.44322981]
#  [-2.70216673 -0.58431589]].	 weights of second layer: [[-1.51025549 -1.5406694 ]]
# New weights:
# weights of first layer: [[-0.71662161  1.44318929]
#  [-2.7021715  -0.58436712]].	 weights of second layer: [[-1.51019102 -1.54064695]]
#
#
#
#
# Iteration: 64
# Old weights:
# weights of first layer: [[-0.71662161  1.44318929]
#  [-2.7021715  -0.58436712]].	 weights of second layer: [[-1.51019102 -1.54064695]]
# New weights:
# weights of first layer: [[-0.71661014  1.44314877]
#  [-2.70217628 -0.58441835]].	 weights of second layer: [[-1.51012657 -1.54062451]]
#
#
#
#
# Iteration: 65
# Old weights:
# weights of first layer: [[-0.71661014  1.44314877]
#  [-2.70217628 -0.58441835]].	 weights of second layer: [[-1.51012657 -1.54062451]]
# New weights:
# weights of first layer: [[-0.71659866  1.44310827]
#  [-2.70218105 -0.58446957]].	 weights of second layer: [[-1.51006214 -1.54060207]]
#
#
#
#
# Iteration: 66
# Old weights:
# weights of first layer: [[-0.71659866  1.44310827]
#  [-2.70218105 -0.58446957]].	 weights of second layer: [[-1.51006214 -1.54060207]]
# New weights:
# weights of first layer: [[-0.71658718  1.44306777]
#  [-2.70218582 -0.58452078]].	 weights of second layer: [[-1.50999772 -1.54057965]]
#
#
#
#
# Iteration: 67
# Old weights:
# weights of first layer: [[-0.71658718  1.44306777]
#  [-2.70218582 -0.58452078]].	 weights of second layer: [[-1.50999772 -1.54057965]]
# New weights:
# weights of first layer: [[-0.71657569  1.44302728]
#  [-2.7021906  -0.58457199]].	 weights of second layer: [[-1.50993332 -1.54055723]]
#
#
#
#
# Iteration: 68
# Old weights:
# weights of first layer: [[-0.71657569  1.44302728]
#  [-2.7021906  -0.58457199]].	 weights of second layer: [[-1.50993332 -1.54055723]]
# New weights:
# weights of first layer: [[-0.7165642   1.4429868 ]
#  [-2.70219537 -0.5846232 ]].	 weights of second layer: [[-1.50986893 -1.54053483]]
#
#
#
#
# Iteration: 69
# Old weights:
# weights of first layer: [[-0.7165642   1.4429868 ]
#  [-2.70219537 -0.5846232 ]].	 weights of second layer: [[-1.50986893 -1.54053483]]
# New weights:
# weights of first layer: [[-0.7165527   1.44294633]
#  [-2.70220014 -0.58467439]].	 weights of second layer: [[-1.50980456 -1.54051243]]
#
#
#
#
# Iteration: 70
# Old weights:
# weights of first layer: [[-0.7165527   1.44294633]
#  [-2.70220014 -0.58467439]].	 weights of second layer: [[-1.50980456 -1.54051243]]
# New weights:
# weights of first layer: [[-0.7165412   1.44290587]
#  [-2.7022049  -0.58472558]].	 weights of second layer: [[-1.5097402  -1.54049005]]
#
#
#
#
# Iteration: 71
# Old weights:
# weights of first layer: [[-0.7165412   1.44290587]
#  [-2.7022049  -0.58472558]].	 weights of second layer: [[-1.5097402  -1.54049005]]
# New weights:
# weights of first layer: [[-0.71652969  1.44286542]
#  [-2.70220967 -0.58477676]].	 weights of second layer: [[-1.50967586 -1.54046767]]
#
#
#
#
# Iteration: 72
# Old weights:
# weights of first layer: [[-0.71652969  1.44286542]
#  [-2.70220967 -0.58477676]].	 weights of second layer: [[-1.50967586 -1.54046767]]
# New weights:
# weights of first layer: [[-0.71651818  1.44282498]
#  [-2.70221444 -0.58482794]].	 weights of second layer: [[-1.50961153 -1.54044531]]
#
#
#
#
# Iteration: 73
# Old weights:
# weights of first layer: [[-0.71651818  1.44282498]
#  [-2.70221444 -0.58482794]].	 weights of second layer: [[-1.50961153 -1.54044531]]
# New weights:
# weights of first layer: [[-0.71650666  1.44278455]
#  [-2.7022192  -0.58487911]].	 weights of second layer: [[-1.50954722 -1.54042295]]
#
#
#
#
# Iteration: 74
# Old weights:
# weights of first layer: [[-0.71650666  1.44278455]
#  [-2.7022192  -0.58487911]].	 weights of second layer: [[-1.50954722 -1.54042295]]
# New weights:
# weights of first layer: [[-0.71649514  1.44274413]
#  [-2.70222397 -0.58493027]].	 weights of second layer: [[-1.50948293 -1.54040061]]
#
#
#
#
# Iteration: 75
# Old weights:
# weights of first layer: [[-0.71649514  1.44274413]
#  [-2.70222397 -0.58493027]].	 weights of second layer: [[-1.50948293 -1.54040061]]
# New weights:
# weights of first layer: [[-0.71648361  1.44270372]
#  [-2.70222873 -0.58498143]].	 weights of second layer: [[-1.50941865 -1.54037827]]
#
#
#
#
# Iteration: 76
# Old weights:
# weights of first layer: [[-0.71648361  1.44270372]
#  [-2.70222873 -0.58498143]].	 weights of second layer: [[-1.50941865 -1.54037827]]
# New weights:
# weights of first layer: [[-0.71647208  1.44266332]
#  [-2.70223349 -0.58503258]].	 weights of second layer: [[-1.50935438 -1.54035594]]
#
#
#
#
# Iteration: 77
# Old weights:
# weights of first layer: [[-0.71647208  1.44266332]
#  [-2.70223349 -0.58503258]].	 weights of second layer: [[-1.50935438 -1.54035594]]
# New weights:
# weights of first layer: [[-0.71646055  1.44262292]
#  [-2.70223825 -0.58508372]].	 weights of second layer: [[-1.50929013 -1.54033363]]
#
#
#
#
# Iteration: 78
# Old weights:
# weights of first layer: [[-0.71646055  1.44262292]
#  [-2.70223825 -0.58508372]].	 weights of second layer: [[-1.50929013 -1.54033363]]
# New weights:
# weights of first layer: [[-0.71644901  1.44258254]
#  [-2.70224301 -0.58513486]].	 weights of second layer: [[-1.5092259  -1.54031132]]
#
#
#
#
# Iteration: 79
# Old weights:
# weights of first layer: [[-0.71644901  1.44258254]
#  [-2.70224301 -0.58513486]].	 weights of second layer: [[-1.5092259  -1.54031132]]
# New weights:
# weights of first layer: [[-0.71643746  1.44254216]
#  [-2.70224777 -0.58518599]].	 weights of second layer: [[-1.50916168 -1.54028903]]
#
#
#
#
# Iteration: 80
# Old weights:
# weights of first layer: [[-0.71643746  1.44254216]
#  [-2.70224777 -0.58518599]].	 weights of second layer: [[-1.50916168 -1.54028903]]
# New weights:
# weights of first layer: [[-0.71642591  1.4425018 ]
#  [-2.70225253 -0.58523711]].	 weights of second layer: [[-1.50909748 -1.54026674]]
#
#
#
#
# Iteration: 81
# Old weights:
# weights of first layer: [[-0.71642591  1.4425018 ]
#  [-2.70225253 -0.58523711]].	 weights of second layer: [[-1.50909748 -1.54026674]]
# New weights:
# weights of first layer: [[-0.71641436  1.44246144]
#  [-2.70225729 -0.58528823]].	 weights of second layer: [[-1.50903329 -1.54024446]]
#
#
#
#
# Iteration: 82
# Old weights:
# weights of first layer: [[-0.71641436  1.44246144]
#  [-2.70225729 -0.58528823]].	 weights of second layer: [[-1.50903329 -1.54024446]]
# New weights:
# weights of first layer: [[-0.7164028   1.4424211 ]
#  [-2.70226204 -0.58533934]].	 weights of second layer: [[-1.50896912 -1.5402222 ]]
#
#
#
#
# Iteration: 83
# Old weights:
# weights of first layer: [[-0.7164028   1.4424211 ]
#  [-2.70226204 -0.58533934]].	 weights of second layer: [[-1.50896912 -1.5402222 ]]
# New weights:
# weights of first layer: [[-0.71639123  1.44238076]
#  [-2.7022668  -0.58539044]].	 weights of second layer: [[-1.50890496 -1.54019994]]
#
#
#
#
# Iteration: 84
# Old weights:
# weights of first layer: [[-0.71639123  1.44238076]
#  [-2.7022668  -0.58539044]].	 weights of second layer: [[-1.50890496 -1.54019994]]
# New weights:
# weights of first layer: [[-0.71637966  1.44234043]
#  [-2.70227155 -0.58544154]].	 weights of second layer: [[-1.50884082 -1.54017769]]
#
#
#
#
# Iteration: 85
# Old weights:
# weights of first layer: [[-0.71637966  1.44234043]
#  [-2.70227155 -0.58544154]].	 weights of second layer: [[-1.50884082 -1.54017769]]
# New weights:
# weights of first layer: [[-0.71636809  1.44230011]
#  [-2.7022763  -0.58549263]].	 weights of second layer: [[-1.50877669 -1.54015545]]
#
#
#
#
# Iteration: 86
# Old weights:
# weights of first layer: [[-0.71636809  1.44230011]
#  [-2.7022763  -0.58549263]].	 weights of second layer: [[-1.50877669 -1.54015545]]
# New weights:
# weights of first layer: [[-0.71635651  1.4422598 ]
#  [-2.70228105 -0.58554372]].	 weights of second layer: [[-1.50871258 -1.54013323]]
#
#
#
#
# Iteration: 87
# Old weights:
# weights of first layer: [[-0.71635651  1.4422598 ]
#  [-2.70228105 -0.58554372]].	 weights of second layer: [[-1.50871258 -1.54013323]]
# New weights:
# weights of first layer: [[-0.71634493  1.4422195 ]
#  [-2.7022858  -0.5855948 ]].	 weights of second layer: [[-1.50864848 -1.54011101]]
#
#
#
#
# Iteration: 88
# Old weights:
# weights of first layer: [[-0.71634493  1.4422195 ]
#  [-2.7022858  -0.5855948 ]].	 weights of second layer: [[-1.50864848 -1.54011101]]
# New weights:
# weights of first layer: [[-0.71633334  1.44217921]
#  [-2.70229055 -0.58564587]].	 weights of second layer: [[-1.5085844 -1.5400888]]
#
#
#
#
# Iteration: 89
# Old weights:
# weights of first layer: [[-0.71633334  1.44217921]
#  [-2.70229055 -0.58564587]].	 weights of second layer: [[-1.5085844 -1.5400888]]
# New weights:
# weights of first layer: [[-0.71632175  1.44213893]
#  [-2.7022953  -0.58569693]].	 weights of second layer: [[-1.50852034 -1.5400666 ]]
#
#
#
#
# Iteration: 90
# Old weights:
# weights of first layer: [[-0.71632175  1.44213893]
#  [-2.7022953  -0.58569693]].	 weights of second layer: [[-1.50852034 -1.5400666 ]]
# New weights:
# weights of first layer: [[-0.71631015  1.44209866]
#  [-2.70230005 -0.58574799]].	 weights of second layer: [[-1.50845629 -1.54004441]]
#
#
#
#
# Iteration: 91
# Old weights:
# weights of first layer: [[-0.71631015  1.44209866]
#  [-2.70230005 -0.58574799]].	 weights of second layer: [[-1.50845629 -1.54004441]]
# New weights:
# weights of first layer: [[-0.71629855  1.4420584 ]
#  [-2.70230479 -0.58579905]].	 weights of second layer: [[-1.50839225 -1.54002223]]
#
#
#
#
# Iteration: 92
# Old weights:
# weights of first layer: [[-0.71629855  1.4420584 ]
#  [-2.70230479 -0.58579905]].	 weights of second layer: [[-1.50839225 -1.54002223]]
# New weights:
# weights of first layer: [[-0.71628694  1.44201815]
#  [-2.70230954 -0.58585009]].	 weights of second layer: [[-1.50832823 -1.54000007]]
#
#
#
#
# Iteration: 93
# Old weights:
# weights of first layer: [[-0.71628694  1.44201815]
#  [-2.70230954 -0.58585009]].	 weights of second layer: [[-1.50832823 -1.54000007]]
# New weights:
# weights of first layer: [[-0.71627533  1.4419779 ]
#  [-2.70231428 -0.58590113]].	 weights of second layer: [[-1.50826423 -1.53997791]]
#
#
#
#
# Iteration: 94
# Old weights:
# weights of first layer: [[-0.71627533  1.4419779 ]
#  [-2.70231428 -0.58590113]].	 weights of second layer: [[-1.50826423 -1.53997791]]
# New weights:
# weights of first layer: [[-0.71626371  1.44193767]
#  [-2.70231903 -0.58595216]].	 weights of second layer: [[-1.50820024 -1.53995576]]
#
#
#
#
# Iteration: 95
# Old weights:
# weights of first layer: [[-0.71626371  1.44193767]
#  [-2.70231903 -0.58595216]].	 weights of second layer: [[-1.50820024 -1.53995576]]
# New weights:
# weights of first layer: [[-0.71625209  1.44189744]
#  [-2.70232377 -0.58600319]].	 weights of second layer: [[-1.50813626 -1.53993362]]
#
#
#
#
# Iteration: 96
# Old weights:
# weights of first layer: [[-0.71625209  1.44189744]
#  [-2.70232377 -0.58600319]].	 weights of second layer: [[-1.50813626 -1.53993362]]
# New weights:
# weights of first layer: [[-0.71624046  1.44185723]
#  [-2.70232851 -0.58605421]].	 weights of second layer: [[-1.5080723  -1.53991149]]
#
#
#
#
# Iteration: 97
# Old weights:
# weights of first layer: [[-0.71624046  1.44185723]
#  [-2.70232851 -0.58605421]].	 weights of second layer: [[-1.5080723  -1.53991149]]
# New weights:
# weights of first layer: [[-0.71622883  1.44181702]
#  [-2.70233325 -0.58610523]].	 weights of second layer: [[-1.50800836 -1.53988937]]
#
#
#
#
# Iteration: 98
# Old weights:
# weights of first layer: [[-0.71622883  1.44181702]
#  [-2.70233325 -0.58610523]].	 weights of second layer: [[-1.50800836 -1.53988937]]
# New weights:
# weights of first layer: [[-0.7162172   1.44177682]
#  [-2.70233799 -0.58615623]].	 weights of second layer: [[-1.50794443 -1.53986726]]
#
#
#
#
# Iteration: 99
# Old weights:
# weights of first layer: [[-0.7162172   1.44177682]
#  [-2.70233799 -0.58615623]].	 weights of second layer: [[-1.50794443 -1.53986726]]
# New weights:
# weights of first layer: [[-0.71620556  1.44173664]
#  [-2.70234272 -0.58620723]].	 weights of second layer: [[-1.50788052 -1.53984516]]
#
#
#
#
# Iteration: 100
# Old weights:
# weights of first layer: [[-0.71620556  1.44173664]
#  [-2.70234272 -0.58620723]].	 weights of second layer: [[-1.50788052 -1.53984516]]
# New weights:
# weights of first layer: [[-0.71619391  1.44169646]
#  [-2.70234746 -0.58625823]].	 weights of second layer: [[-1.50781662 -1.53982307]]
#
#
#
#
# Iteration: 101
# Old weights:
# weights of first layer: [[-0.71619391  1.44169646]
#  [-2.70234746 -0.58625823]].	 weights of second layer: [[-1.50781662 -1.53982307]]
# New weights:
# weights of first layer: [[-0.71618226  1.44165629]
#  [-2.7023522  -0.58630922]].	 weights of second layer: [[-1.50775274 -1.53980099]]
#
#
#
#
# Iteration: 102
# Old weights:
# weights of first layer: [[-0.71618226  1.44165629]
#  [-2.7023522  -0.58630922]].	 weights of second layer: [[-1.50775274 -1.53980099]]
# New weights:
# weights of first layer: [[-0.71617061  1.44161613]
#  [-2.70235693 -0.5863602 ]].	 weights of second layer: [[-1.50768887 -1.53977892]]
#
#
#
#
# Iteration: 103
# Old weights:
# weights of first layer: [[-0.71617061  1.44161613]
#  [-2.70235693 -0.5863602 ]].	 weights of second layer: [[-1.50768887 -1.53977892]]
# New weights:
# weights of first layer: [[-0.71615895  1.44157598]
#  [-2.70236166 -0.58641117]].	 weights of second layer: [[-1.50762502 -1.53975685]]
#
#
#
#
# Iteration: 104
# Old weights:
# weights of first layer: [[-0.71615895  1.44157598]
#  [-2.70236166 -0.58641117]].	 weights of second layer: [[-1.50762502 -1.53975685]]
# New weights:
# weights of first layer: [[-0.71614728  1.44153584]
#  [-2.70236639 -0.58646214]].	 weights of second layer: [[-1.50756118 -1.5397348 ]]
#
#
#
#
# Iteration: 105
# Old weights:
# weights of first layer: [[-0.71614728  1.44153584]
#  [-2.70236639 -0.58646214]].	 weights of second layer: [[-1.50756118 -1.5397348 ]]
# New weights:
# weights of first layer: [[-0.71613561  1.44149571]
#  [-2.70237113 -0.5865131 ]].	 weights of second layer: [[-1.50749736 -1.53971276]]
#
#
#
#
# Iteration: 106
# Old weights:
# weights of first layer: [[-0.71613561  1.44149571]
#  [-2.70237113 -0.5865131 ]].	 weights of second layer: [[-1.50749736 -1.53971276]]
# New weights:
# weights of first layer: [[-0.71612394  1.44145559]
#  [-2.70237586 -0.58656406]].	 weights of second layer: [[-1.50743355 -1.53969073]]
#
#
#
#
# Iteration: 107
# Old weights:
# weights of first layer: [[-0.71612394  1.44145559]
#  [-2.70237586 -0.58656406]].	 weights of second layer: [[-1.50743355 -1.53969073]]
# New weights:
# weights of first layer: [[-0.71611226  1.44141547]
#  [-2.70238058 -0.58661501]].	 weights of second layer: [[-1.50736976 -1.53966871]]
#
#
#
#
# Iteration: 108
# Old weights:
# weights of first layer: [[-0.71611226  1.44141547]
#  [-2.70238058 -0.58661501]].	 weights of second layer: [[-1.50736976 -1.53966871]]
# New weights:
# weights of first layer: [[-0.71610058  1.44137537]
#  [-2.70238531 -0.58666595]].	 weights of second layer: [[-1.50730599 -1.5396467 ]]
#
#
#
#
# Iteration: 109
# Old weights:
# weights of first layer: [[-0.71610058  1.44137537]
#  [-2.70238531 -0.58666595]].	 weights of second layer: [[-1.50730599 -1.5396467 ]]
# New weights:
# weights of first layer: [[-0.71608889  1.44133527]
#  [-2.70239004 -0.58671689]].	 weights of second layer: [[-1.50724223 -1.53962469]]
#
#
#
#
# Iteration: 110
# Old weights:
# weights of first layer: [[-0.71608889  1.44133527]
#  [-2.70239004 -0.58671689]].	 weights of second layer: [[-1.50724223 -1.53962469]]
# New weights:
# weights of first layer: [[-0.7160772   1.44129519]
#  [-2.70239476 -0.58676782]].	 weights of second layer: [[-1.50717848 -1.5396027 ]]
#
#
#
#
# Iteration: 111
# Old weights:
# weights of first layer: [[-0.7160772   1.44129519]
#  [-2.70239476 -0.58676782]].	 weights of second layer: [[-1.50717848 -1.5396027 ]]
# New weights:
# weights of first layer: [[-0.7160655   1.44125511]
#  [-2.70239949 -0.58681874]].	 weights of second layer: [[-1.50711475 -1.53958072]]
#
#
#
#
# Iteration: 112
# Old weights:
# weights of first layer: [[-0.7160655   1.44125511]
#  [-2.70239949 -0.58681874]].	 weights of second layer: [[-1.50711475 -1.53958072]]
# New weights:
# weights of first layer: [[-0.7160538   1.44121505]
#  [-2.70240421 -0.58686966]].	 weights of second layer: [[-1.50705104 -1.53955874]]
#
#
#
#
# Iteration: 113
# Old weights:
# weights of first layer: [[-0.7160538   1.44121505]
#  [-2.70240421 -0.58686966]].	 weights of second layer: [[-1.50705104 -1.53955874]]
# New weights:
# weights of first layer: [[-0.71604209  1.44117499]
#  [-2.70240894 -0.58692057]].	 weights of second layer: [[-1.50698734 -1.53953678]]
#
#
#
#
# Iteration: 114
# Old weights:
# weights of first layer: [[-0.71604209  1.44117499]
#  [-2.70240894 -0.58692057]].	 weights of second layer: [[-1.50698734 -1.53953678]]
# New weights:
# weights of first layer: [[-0.71603038  1.44113494]
#  [-2.70241366 -0.58697147]].	 weights of second layer: [[-1.50692365 -1.53951483]]
#
#
#
#
# Iteration: 115
# Old weights:
# weights of first layer: [[-0.71603038  1.44113494]
#  [-2.70241366 -0.58697147]].	 weights of second layer: [[-1.50692365 -1.53951483]]
# New weights:
# weights of first layer: [[-0.71601866  1.4410949 ]
#  [-2.70241838 -0.58702237]].	 weights of second layer: [[-1.50685998 -1.53949288]]
#
#
#
#
# Iteration: 116
# Old weights:
# weights of first layer: [[-0.71601866  1.4410949 ]
#  [-2.70241838 -0.58702237]].	 weights of second layer: [[-1.50685998 -1.53949288]]
# New weights:
# weights of first layer: [[-0.71600694  1.44105488]
#  [-2.7024231  -0.58707326]].	 weights of second layer: [[-1.50679633 -1.53947095]]
#
#
#
#
# Iteration: 117
# Old weights:
# weights of first layer: [[-0.71600694  1.44105488]
#  [-2.7024231  -0.58707326]].	 weights of second layer: [[-1.50679633 -1.53947095]]
# New weights:
# weights of first layer: [[-0.71599522  1.44101486]
#  [-2.70242781 -0.58712415]].	 weights of second layer: [[-1.50673269 -1.53944902]]
#
#
#
#
# Iteration: 118
# Old weights:
# weights of first layer: [[-0.71599522  1.44101486]
#  [-2.70242781 -0.58712415]].	 weights of second layer: [[-1.50673269 -1.53944902]]
# New weights:
# weights of first layer: [[-0.71598349  1.44097485]
#  [-2.70243253 -0.58717503]].	 weights of second layer: [[-1.50666906 -1.53942711]]
#
#
#
#
# Iteration: 119
# Old weights:
# weights of first layer: [[-0.71598349  1.44097485]
#  [-2.70243253 -0.58717503]].	 weights of second layer: [[-1.50666906 -1.53942711]]
# New weights:
# weights of first layer: [[-0.71597175  1.44093484]
#  [-2.70243725 -0.5872259 ]].	 weights of second layer: [[-1.50660545 -1.5394052 ]]
#
#
#
#
# Iteration: 120
# Old weights:
# weights of first layer: [[-0.71597175  1.44093484]
#  [-2.70243725 -0.5872259 ]].	 weights of second layer: [[-1.50660545 -1.5394052 ]]
# New weights:
# weights of first layer: [[-0.71596001  1.44089485]
#  [-2.70244196 -0.58727676]].	 weights of second layer: [[-1.50654186 -1.53938331]]
#
#
#
#
# Iteration: 121
# Old weights:
# weights of first layer: [[-0.71596001  1.44089485]
#  [-2.70244196 -0.58727676]].	 weights of second layer: [[-1.50654186 -1.53938331]]
# New weights:
# weights of first layer: [[-0.71594827  1.44085487]
#  [-2.70244668 -0.58732762]].	 weights of second layer: [[-1.50647828 -1.53936142]]
#
#
#
#
# Iteration: 122
# Old weights:
# weights of first layer: [[-0.71594827  1.44085487]
#  [-2.70244668 -0.58732762]].	 weights of second layer: [[-1.50647828 -1.53936142]]
# New weights:
# weights of first layer: [[-0.71593652  1.4408149 ]
#  [-2.70245139 -0.58737848]].	 weights of second layer: [[-1.50641472 -1.53933955]]
#
#
#
#
# Iteration: 123
# Old weights:
# weights of first layer: [[-0.71593652  1.4408149 ]
#  [-2.70245139 -0.58737848]].	 weights of second layer: [[-1.50641472 -1.53933955]]
# New weights:
# weights of first layer: [[-0.71592477  1.44077493]
#  [-2.7024561  -0.58742932]].	 weights of second layer: [[-1.50635117 -1.53931768]]
#
#
#
#
# Iteration: 124
# Old weights:
# weights of first layer: [[-0.71592477  1.44077493]
#  [-2.7024561  -0.58742932]].	 weights of second layer: [[-1.50635117 -1.53931768]]
# New weights:
# weights of first layer: [[-0.71591301  1.44073498]
#  [-2.70246081 -0.58748016]].	 weights of second layer: [[-1.50628763 -1.53929582]]
#
#
#
#
# Iteration: 125
# Old weights:
# weights of first layer: [[-0.71591301  1.44073498]
#  [-2.70246081 -0.58748016]].	 weights of second layer: [[-1.50628763 -1.53929582]]
# New weights:
# weights of first layer: [[-0.71590124  1.44069503]
#  [-2.70246552 -0.58753099]].	 weights of second layer: [[-1.50622412 -1.53927398]]
#
#
#
#
# Iteration: 126
# Old weights:
# weights of first layer: [[-0.71590124  1.44069503]
#  [-2.70246552 -0.58753099]].	 weights of second layer: [[-1.50622412 -1.53927398]]
# New weights:
# weights of first layer: [[-0.71588948  1.4406551 ]
#  [-2.70247023 -0.58758182]].	 weights of second layer: [[-1.50616061 -1.53925214]]
#
#
#
#
# Iteration: 127
# Old weights:
# weights of first layer: [[-0.71588948  1.4406551 ]
#  [-2.70247023 -0.58758182]].	 weights of second layer: [[-1.50616061 -1.53925214]]
# New weights:
# weights of first layer: [[-0.7158777   1.44061517]
#  [-2.70247494 -0.58763264]].	 weights of second layer: [[-1.50609713 -1.53923031]]
#
#
#
#
# Iteration: 128
# Old weights:
# weights of first layer: [[-0.7158777   1.44061517]
#  [-2.70247494 -0.58763264]].	 weights of second layer: [[-1.50609713 -1.53923031]]
# New weights:
# weights of first layer: [[-0.71586593  1.44057525]
#  [-2.70247964 -0.58768346]].	 weights of second layer: [[-1.50603365 -1.53920849]]
#
#
#
#
# Iteration: 129
# Old weights:
# weights of first layer: [[-0.71586593  1.44057525]
#  [-2.70247964 -0.58768346]].	 weights of second layer: [[-1.50603365 -1.53920849]]
# New weights:
# weights of first layer: [[-0.71585414  1.44053534]
#  [-2.70248435 -0.58773427]].	 weights of second layer: [[-1.50597019 -1.53918669]]
#
#
#
#
# Iteration: 130
# Old weights:
# weights of first layer: [[-0.71585414  1.44053534]
#  [-2.70248435 -0.58773427]].	 weights of second layer: [[-1.50597019 -1.53918669]]
# New weights:
# weights of first layer: [[-0.71584236  1.44049544]
#  [-2.70248905 -0.58778507]].	 weights of second layer: [[-1.50590675 -1.53916489]]
#
#
#
#
# Iteration: 131
# Old weights:
# weights of first layer: [[-0.71584236  1.44049544]
#  [-2.70248905 -0.58778507]].	 weights of second layer: [[-1.50590675 -1.53916489]]
# New weights:
# weights of first layer: [[-0.71583057  1.44045555]
#  [-2.70249376 -0.58783586]].	 weights of second layer: [[-1.50584332 -1.5391431 ]]
#
#
#
#
# Iteration: 132
# Old weights:
# weights of first layer: [[-0.71583057  1.44045555]
#  [-2.70249376 -0.58783586]].	 weights of second layer: [[-1.50584332 -1.5391431 ]]
# New weights:
# weights of first layer: [[-0.71581877  1.44041567]
#  [-2.70249846 -0.58788665]].	 weights of second layer: [[-1.50577991 -1.53912132]]
#
#
#
#
# Iteration: 133
# Old weights:
# weights of first layer: [[-0.71581877  1.44041567]
#  [-2.70249846 -0.58788665]].	 weights of second layer: [[-1.50577991 -1.53912132]]
# New weights:
# weights of first layer: [[-0.71580697  1.4403758 ]
#  [-2.70250316 -0.58793743]].	 weights of second layer: [[-1.50571651 -1.53909955]]
#
#
#
#
# Iteration: 134
# Old weights:
# weights of first layer: [[-0.71580697  1.4403758 ]
#  [-2.70250316 -0.58793743]].	 weights of second layer: [[-1.50571651 -1.53909955]]
# New weights:
# weights of first layer: [[-0.71579516  1.44033594]
#  [-2.70250786 -0.58798821]].	 weights of second layer: [[-1.50565313 -1.53907779]]
#
#
#
#
# Iteration: 135
# Old weights:
# weights of first layer: [[-0.71579516  1.44033594]
#  [-2.70250786 -0.58798821]].	 weights of second layer: [[-1.50565313 -1.53907779]]
# New weights:
# weights of first layer: [[-0.71578335  1.44029609]
#  [-2.70251256 -0.58803898]].	 weights of second layer: [[-1.50558977 -1.53905604]]
#
#
#
#
# Iteration: 136
# Old weights:
# weights of first layer: [[-0.71578335  1.44029609]
#  [-2.70251256 -0.58803898]].	 weights of second layer: [[-1.50558977 -1.53905604]]
# New weights:
# weights of first layer: [[-0.71577154  1.44025624]
#  [-2.70251726 -0.58808974]].	 weights of second layer: [[-1.50552641 -1.5390343 ]]
#
#
#
#
# Iteration: 137
# Old weights:
# weights of first layer: [[-0.71577154  1.44025624]
#  [-2.70251726 -0.58808974]].	 weights of second layer: [[-1.50552641 -1.5390343 ]]
# New weights:
# weights of first layer: [[-0.71575972  1.44021641]
#  [-2.70252196 -0.5881405 ]].	 weights of second layer: [[-1.50546308 -1.53901257]]
#
#
#
#
# Iteration: 138
# Old weights:
# weights of first layer: [[-0.71575972  1.44021641]
#  [-2.70252196 -0.5881405 ]].	 weights of second layer: [[-1.50546308 -1.53901257]]
# New weights:
# weights of first layer: [[-0.7157479   1.44017658]
#  [-2.70252665 -0.58819125]].	 weights of second layer: [[-1.50539975 -1.53899085]]
#
#
#
#
# Iteration: 139
# Old weights:
# weights of first layer: [[-0.7157479   1.44017658]
#  [-2.70252665 -0.58819125]].	 weights of second layer: [[-1.50539975 -1.53899085]]
# New weights:
# weights of first layer: [[-0.71573607  1.44013677]
#  [-2.70253135 -0.58824199]].	 weights of second layer: [[-1.50533645 -1.53896914]]
#
#
#
#
# Iteration: 140
# Old weights:
# weights of first layer: [[-0.71573607  1.44013677]
#  [-2.70253135 -0.58824199]].	 weights of second layer: [[-1.50533645 -1.53896914]]
# New weights:
# weights of first layer: [[-0.71572424  1.44009696]
#  [-2.70253604 -0.58829273]].	 weights of second layer: [[-1.50527316 -1.53894744]]
#
#
#
#
# Iteration: 141
# Old weights:
# weights of first layer: [[-0.71572424  1.44009696]
#  [-2.70253604 -0.58829273]].	 weights of second layer: [[-1.50527316 -1.53894744]]
# New weights:
# weights of first layer: [[-0.7157124   1.44005716]
#  [-2.70254073 -0.58834346]].	 weights of second layer: [[-1.50520988 -1.53892575]]
#
#
#
#
# Iteration: 142
# Old weights:
# weights of first layer: [[-0.7157124   1.44005716]
#  [-2.70254073 -0.58834346]].	 weights of second layer: [[-1.50520988 -1.53892575]]
# New weights:
# weights of first layer: [[-0.71570055  1.44001738]
#  [-2.70254543 -0.58839419]].	 weights of second layer: [[-1.50514662 -1.53890406]]
#
#
#
#
# Iteration: 143
# Old weights:
# weights of first layer: [[-0.71570055  1.44001738]
#  [-2.70254543 -0.58839419]].	 weights of second layer: [[-1.50514662 -1.53890406]]
# New weights:
# weights of first layer: [[-0.71568871  1.4399776 ]
#  [-2.70255012 -0.5884449 ]].	 weights of second layer: [[-1.50508337 -1.53888239]]
#
#
#
#
# Iteration: 144
# Old weights:
# weights of first layer: [[-0.71568871  1.4399776 ]
#  [-2.70255012 -0.5884449 ]].	 weights of second layer: [[-1.50508337 -1.53888239]]
# New weights:
# weights of first layer: [[-0.71567686  1.43993783]
#  [-2.70255481 -0.58849562]].	 weights of second layer: [[-1.50502014 -1.53886073]]
#
#
#
#
# Iteration: 145
# Old weights:
# weights of first layer: [[-0.71567686  1.43993783]
#  [-2.70255481 -0.58849562]].	 weights of second layer: [[-1.50502014 -1.53886073]]
# New weights:
# weights of first layer: [[-0.715665    1.43989807]
#  [-2.7025595  -0.58854632]].	 weights of second layer: [[-1.50495692 -1.53883908]]
#
#
#
#
# Iteration: 146
# Old weights:
# weights of first layer: [[-0.715665    1.43989807]
#  [-2.7025595  -0.58854632]].	 weights of second layer: [[-1.50495692 -1.53883908]]
# New weights:
# weights of first layer: [[-0.71565314  1.43985831]
#  [-2.70256418 -0.58859702]].	 weights of second layer: [[-1.50489372 -1.53881743]]
#
#
#
#
# Iteration: 147
# Old weights:
# weights of first layer: [[-0.71565314  1.43985831]
#  [-2.70256418 -0.58859702]].	 weights of second layer: [[-1.50489372 -1.53881743]]
# New weights:
# weights of first layer: [[-0.71564127  1.43981857]
#  [-2.70256887 -0.58864771]].	 weights of second layer: [[-1.50483054 -1.5387958 ]]
#
#
#
#
# Iteration: 148
# Old weights:
# weights of first layer: [[-0.71564127  1.43981857]
#  [-2.70256887 -0.58864771]].	 weights of second layer: [[-1.50483054 -1.5387958 ]]
# New weights:
# weights of first layer: [[-0.7156294   1.43977884]
#  [-2.70257356 -0.5886984 ]].	 weights of second layer: [[-1.50476736 -1.53877417]]
#
#
#
#
# Iteration: 149
# Old weights:
# weights of first layer: [[-0.7156294   1.43977884]
#  [-2.70257356 -0.5886984 ]].	 weights of second layer: [[-1.50476736 -1.53877417]]
# New weights:
# weights of first layer: [[-0.71561753  1.43973912]
#  [-2.70257824 -0.58874908]].	 weights of second layer: [[-1.50470421 -1.53875256]]
#
#
#
#
# Iteration: 150
# Old weights:
# weights of first layer: [[-0.71561753  1.43973912]
#  [-2.70257824 -0.58874908]].	 weights of second layer: [[-1.50470421 -1.53875256]]
# New weights:
# weights of first layer: [[-0.71560565  1.4396994 ]
#  [-2.70258292 -0.58879976]].	 weights of second layer: [[-1.50464107 -1.53873095]]
#
#
#
#
# Iteration: 151
# Old weights:
# weights of first layer: [[-0.71560565  1.4396994 ]
#  [-2.70258292 -0.58879976]].	 weights of second layer: [[-1.50464107 -1.53873095]]
# New weights:
# weights of first layer: [[-0.71559376  1.4396597 ]
#  [-2.70258761 -0.58885042]].	 weights of second layer: [[-1.50457794 -1.53870936]]
#
#
#
#
# Iteration: 152
# Old weights:
# weights of first layer: [[-0.71559376  1.4396597 ]
#  [-2.70258761 -0.58885042]].	 weights of second layer: [[-1.50457794 -1.53870936]]
# New weights:
# weights of first layer: [[-0.71558187  1.43962   ]
#  [-2.70259229 -0.58890108]].	 weights of second layer: [[-1.50451483 -1.53868777]]
#
#
#
#
# Iteration: 153
# Old weights:
# weights of first layer: [[-0.71558187  1.43962   ]
#  [-2.70259229 -0.58890108]].	 weights of second layer: [[-1.50451483 -1.53868777]]
# New weights:
# weights of first layer: [[-0.71556998  1.43958031]
#  [-2.70259697 -0.58895174]].	 weights of second layer: [[-1.50445173 -1.5386662 ]]
#
#
#
#
# Iteration: 154
# Old weights:
# weights of first layer: [[-0.71556998  1.43958031]
#  [-2.70259697 -0.58895174]].	 weights of second layer: [[-1.50445173 -1.5386662 ]]
# New weights:
# weights of first layer: [[-0.71555808  1.43954064]
# ...
#
#
#
#
# Iteration: 950
# Old weights:
# weights of first layer: [[-0.7047895   1.41070943]
#  [-2.70602538 -0.62739988]].	 weights of second layer: [[-1.4586482  -1.52434042]]
# New weights:
# weights of first layer: [[-0.70477449  1.41067633]
#  [-2.70602936 -0.627446  ]].	 weights of second layer: [[-1.4585958  -1.52432575]]
#
#
#
#
# Iteration: 951
# Old weights:
# weights of first layer: [[-0.70477449  1.41067633]
#  [-2.70602936 -0.627446  ]].	 weights of second layer: [[-1.4585958  -1.52432575]]
# New weights:
# weights of first layer: [[-0.70475948  1.41064324]
#  [-2.70603333 -0.62749212]].	 weights of second layer: [[-1.45854342 -1.52431108]]
#
#
#
#
# Iteration: 952
# Old weights:
# weights of first layer: [[-0.70475948  1.41064324]
#  [-2.70603333 -0.62749212]].	 weights of second layer: [[-1.45854342 -1.52431108]]
# New weights:
# weights of first layer: [[-0.70474446  1.41061016]
#  [-2.7060373  -0.62753823]].	 weights of second layer: [[-1.45849104 -1.52429643]]
#
#
#
#
# Iteration: 953
# Old weights:
# weights of first layer: [[-0.70474446  1.41061016]
#  [-2.7060373  -0.62753823]].	 weights of second layer: [[-1.45849104 -1.52429643]]
# New weights:
# weights of first layer: [[-0.70472944  1.41057709]
#  [-2.70604127 -0.62758434]].	 weights of second layer: [[-1.45843868 -1.52428178]]
#
#
#
#
# Iteration: 954
# Old weights:
# weights of first layer: [[-0.70472944  1.41057709]
#  [-2.70604127 -0.62758434]].	 weights of second layer: [[-1.45843868 -1.52428178]]
# New weights:
# weights of first layer: [[-0.70471441  1.41054402]
#  [-2.70604524 -0.62763044]].	 weights of second layer: [[-1.45838633 -1.52426714]]
#
#
#
#
# Iteration: 955
# Old weights:
# weights of first layer: [[-0.70471441  1.41054402]
#  [-2.70604524 -0.62763044]].	 weights of second layer: [[-1.45838633 -1.52426714]]
# New weights:
# weights of first layer: [[-0.70469939  1.41051096]
#  [-2.70604921 -0.62767654]].	 weights of second layer: [[-1.458334   -1.52425251]]
#
#
#
#
# Iteration: 956
# Old weights:
# weights of first layer: [[-0.70469939  1.41051096]
#  [-2.70604921 -0.62767654]].	 weights of second layer: [[-1.458334   -1.52425251]]
# New weights:
# weights of first layer: [[-0.70468435  1.41047791]
#  [-2.70605318 -0.62772263]].	 weights of second layer: [[-1.45828167 -1.52423788]]
#
#
#
#
# Iteration: 957
# Old weights:
# weights of first layer: [[-0.70468435  1.41047791]
#  [-2.70605318 -0.62772263]].	 weights of second layer: [[-1.45828167 -1.52423788]]
# New weights:
# weights of first layer: [[-0.70466932  1.41044487]
#  [-2.70605715 -0.62776872]].	 weights of second layer: [[-1.45822936 -1.52422326]]
#
#
#
#
# Iteration: 958
# Old weights:
# weights of first layer: [[-0.70466932  1.41044487]
#  [-2.70605715 -0.62776872]].	 weights of second layer: [[-1.45822936 -1.52422326]]
# New weights:
# weights of first layer: [[-0.70465428  1.41041183]
#  [-2.70606112 -0.6278148 ]].	 weights of second layer: [[-1.45817706 -1.52420865]]
#
#
#
#
# Iteration: 959
# Old weights:
# weights of first layer: [[-0.70465428  1.41041183]
#  [-2.70606112 -0.6278148 ]].	 weights of second layer: [[-1.45817706 -1.52420865]]
# New weights:
# weights of first layer: [[-0.70463924  1.4103788 ]
#  [-2.70606509 -0.62786088]].	 weights of second layer: [[-1.45812477 -1.52419405]]
#
#
#
#
# Iteration: 960
# Old weights:
# weights of first layer: [[-0.70463924  1.4103788 ]
#  [-2.70606509 -0.62786088]].	 weights of second layer: [[-1.45812477 -1.52419405]]
# New weights:
# weights of first layer: [[-0.7046242   1.41034578]
#  [-2.70606905 -0.62790695]].	 weights of second layer: [[-1.45807249 -1.52417946]]
#
#
#
#
# Iteration: 961
# Old weights:
# weights of first layer: [[-0.7046242   1.41034578]
#  [-2.70606905 -0.62790695]].	 weights of second layer: [[-1.45807249 -1.52417946]]
# New weights:
# weights of first layer: [[-0.70460915  1.41031276]
#  [-2.70607302 -0.62795302]].	 weights of second layer: [[-1.45802022 -1.52416487]]
#
#
#
#
# Iteration: 962
# Old weights:
# weights of first layer: [[-0.70460915  1.41031276]
#  [-2.70607302 -0.62795302]].	 weights of second layer: [[-1.45802022 -1.52416487]]
# New weights:
# weights of first layer: [[-0.7045941   1.41027975]
#  [-2.70607698 -0.62799908]].	 weights of second layer: [[-1.45796797 -1.52415029]]
#
#
#
#
# Iteration: 963
# Old weights:
# weights of first layer: [[-0.7045941   1.41027975]
#  [-2.70607698 -0.62799908]].	 weights of second layer: [[-1.45796797 -1.52415029]]
# New weights:
# weights of first layer: [[-0.70457905  1.41024675]
#  [-2.70608095 -0.62804513]].	 weights of second layer: [[-1.45791573 -1.52413572]]
#
#
#
#
# Iteration: 964
# Old weights:
# weights of first layer: [[-0.70457905  1.41024675]
#  [-2.70608095 -0.62804513]].	 weights of second layer: [[-1.45791573 -1.52413572]]
# New weights:
# weights of first layer: [[-0.70456399  1.41021376]
#  [-2.70608491 -0.62809119]].	 weights of second layer: [[-1.4578635  -1.52412116]]
#
#
#
#
# Iteration: 965
# Old weights:
# weights of first layer: [[-0.70456399  1.41021376]
#  [-2.70608491 -0.62809119]].	 weights of second layer: [[-1.4578635  -1.52412116]]
# New weights:
# weights of first layer: [[-0.70454893  1.41018077]
#  [-2.70608887 -0.62813723]].	 weights of second layer: [[-1.45781128 -1.5241066 ]]
#
#
#
#
# Iteration: 966
# Old weights:
# weights of first layer: [[-0.70454893  1.41018077]
#  [-2.70608887 -0.62813723]].	 weights of second layer: [[-1.45781128 -1.5241066 ]]
# New weights:
# weights of first layer: [[-0.70453386  1.4101478 ]
#  [-2.70609283 -0.62818327]].	 weights of second layer: [[-1.45775907 -1.52409206]]
#
#
#
#
# Iteration: 967
# Old weights:
# weights of first layer: [[-0.70453386  1.4101478 ]
#  [-2.70609283 -0.62818327]].	 weights of second layer: [[-1.45775907 -1.52409206]]
# New weights:
# weights of first layer: [[-0.7045188   1.41011483]
#  [-2.7060968  -0.62822931]].	 weights of second layer: [[-1.45770688 -1.52407752]]
#
#
#
#
# Iteration: 968
# Old weights:
# weights of first layer: [[-0.7045188   1.41011483]
#  [-2.7060968  -0.62822931]].	 weights of second layer: [[-1.45770688 -1.52407752]]
# New weights:
# weights of first layer: [[-0.70450373  1.41008186]
#  [-2.70610076 -0.62827534]].	 weights of second layer: [[-1.4576547  -1.52406298]]
#
#
#
#
# Iteration: 969
# Old weights:
# weights of first layer: [[-0.70450373  1.41008186]
#  [-2.70610076 -0.62827534]].	 weights of second layer: [[-1.4576547  -1.52406298]]
# New weights:
# weights of first layer: [[-0.70448865  1.41004891]
#  [-2.70610472 -0.62832137]].	 weights of second layer: [[-1.45760252 -1.52404846]]
#
#
#
#
# Iteration: 970
# Old weights:
# weights of first layer: [[-0.70448865  1.41004891]
#  [-2.70610472 -0.62832137]].	 weights of second layer: [[-1.45760252 -1.52404846]]
# New weights:
# weights of first layer: [[-0.70447358  1.41001596]
#  [-2.70610867 -0.62836739]].	 weights of second layer: [[-1.45755037 -1.52403394]]
#
#
#
#
# Iteration: 971
# Old weights:
# weights of first layer: [[-0.70447358  1.41001596]
#  [-2.70610867 -0.62836739]].	 weights of second layer: [[-1.45755037 -1.52403394]]
# New weights:
# weights of first layer: [[-0.7044585   1.40998301]
#  [-2.70611263 -0.62841341]].	 weights of second layer: [[-1.45749822 -1.52401943]]
#
#
#
#
# Iteration: 972
# Old weights:
# weights of first layer: [[-0.7044585   1.40998301]
#  [-2.70611263 -0.62841341]].	 weights of second layer: [[-1.45749822 -1.52401943]]
# New weights:
# weights of first layer: [[-0.70444341  1.40995008]
#  [-2.70611659 -0.62845942]].	 weights of second layer: [[-1.45744608 -1.52400493]]
#
#
#
#
# Iteration: 973
# Old weights:
# weights of first layer: [[-0.70444341  1.40995008]
#  [-2.70611659 -0.62845942]].	 weights of second layer: [[-1.45744608 -1.52400493]]
# New weights:
# weights of first layer: [[-0.70442833  1.40991715]
#  [-2.70612055 -0.62850542]].	 weights of second layer: [[-1.45739396 -1.52399044]]
#
#
#
#
# Iteration: 974
# Old weights:
# weights of first layer: [[-0.70442833  1.40991715]
#  [-2.70612055 -0.62850542]].	 weights of second layer: [[-1.45739396 -1.52399044]]
# New weights:
# weights of first layer: [[-0.70441324  1.40988423]
#  [-2.7061245  -0.62855142]].	 weights of second layer: [[-1.45734185 -1.52397595]]
#
#
#
#
# Iteration: 975
# Old weights:
# weights of first layer: [[-0.70441324  1.40988423]
#  [-2.7061245  -0.62855142]].	 weights of second layer: [[-1.45734185 -1.52397595]]
# New weights:
# weights of first layer: [[-0.70439815  1.40985132]
#  [-2.70612846 -0.62859742]].	 weights of second layer: [[-1.45728975 -1.52396147]]
#
#
#
#
# Iteration: 976
# Old weights:
# weights of first layer: [[-0.70439815  1.40985132]
#  [-2.70612846 -0.62859742]].	 weights of second layer: [[-1.45728975 -1.52396147]]
# New weights:
# weights of first layer: [[-0.70438305  1.40981842]
#  [-2.70613241 -0.62864341]].	 weights of second layer: [[-1.45723766 -1.523947  ]]
#
#
#
#
# Iteration: 977
# Old weights:
# weights of first layer: [[-0.70438305  1.40981842]
#  [-2.70613241 -0.62864341]].	 weights of second layer: [[-1.45723766 -1.523947  ]]
# New weights:
# weights of first layer: [[-0.70436795  1.40978552]
#  [-2.70613637 -0.6286894 ]].	 weights of second layer: [[-1.45718559 -1.52393254]]
#
#
#
#
# Iteration: 978
# Old weights:
# weights of first layer: [[-0.70436795  1.40978552]
#  [-2.70613637 -0.6286894 ]].	 weights of second layer: [[-1.45718559 -1.52393254]]
# New weights:
# weights of first layer: [[-0.70435285  1.40975263]
#  [-2.70614032 -0.62873538]].	 weights of second layer: [[-1.45713352 -1.52391808]]
#
#
#
#
# Iteration: 979
# Old weights:
# weights of first layer: [[-0.70435285  1.40975263]
#  [-2.70614032 -0.62873538]].	 weights of second layer: [[-1.45713352 -1.52391808]]
# New weights:
# weights of first layer: [[-0.70433774  1.40971975]
#  [-2.70614427 -0.62878136]].	 weights of second layer: [[-1.45708147 -1.52390364]]
#
#
#
#
# Iteration: 980
# Old weights:
# weights of first layer: [[-0.70433774  1.40971975]
#  [-2.70614427 -0.62878136]].	 weights of second layer: [[-1.45708147 -1.52390364]]
# New weights:
# weights of first layer: [[-0.70432263  1.40968687]
#  [-2.70614822 -0.62882733]].	 weights of second layer: [[-1.45702943 -1.5238892 ]]
#
#
#
#
# Iteration: 981
# Old weights:
# weights of first layer: [[-0.70432263  1.40968687]
#  [-2.70614822 -0.62882733]].	 weights of second layer: [[-1.45702943 -1.5238892 ]]
# New weights:
# weights of first layer: [[-0.70430752  1.409654  ]
#  [-2.70615217 -0.62887329]].	 weights of second layer: [[-1.4569774  -1.52387476]]
#
#
#
#
# Iteration: 982
# Old weights:
# weights of first layer: [[-0.70430752  1.409654  ]
#  [-2.70615217 -0.62887329]].	 weights of second layer: [[-1.4569774  -1.52387476]]
# New weights:
# weights of first layer: [[-0.70429241  1.40962114]
#  [-2.70615612 -0.62891925]].	 weights of second layer: [[-1.45692538 -1.52386034]]
#
#
#
#
# Iteration: 983
# Old weights:
# weights of first layer: [[-0.70429241  1.40962114]
#  [-2.70615612 -0.62891925]].	 weights of second layer: [[-1.45692538 -1.52386034]]
# New weights:
# weights of first layer: [[-0.70427729  1.40958829]
#  [-2.70616007 -0.62896521]].	 weights of second layer: [[-1.45687338 -1.52384592]]
#
#
#
#
# Iteration: 984
# Old weights:
# weights of first layer: [[-0.70427729  1.40958829]
#  [-2.70616007 -0.62896521]].	 weights of second layer: [[-1.45687338 -1.52384592]]
# New weights:
# weights of first layer: [[-0.70426217  1.40955544]
#  [-2.70616402 -0.62901116]].	 weights of second layer: [[-1.45682139 -1.52383151]]
#
#
#
#
# Iteration: 985
# Old weights:
# weights of first layer: [[-0.70426217  1.40955544]
#  [-2.70616402 -0.62901116]].	 weights of second layer: [[-1.45682139 -1.52383151]]
# New weights:
# weights of first layer: [[-0.70424704  1.4095226 ]
#  [-2.70616797 -0.62905711]].	 weights of second layer: [[-1.4567694  -1.52381711]]
#
#
#
#
# Iteration: 986
# Old weights:
# weights of first layer: [[-0.70424704  1.4095226 ]
#  [-2.70616797 -0.62905711]].	 weights of second layer: [[-1.4567694  -1.52381711]]
# New weights:
# weights of first layer: [[-0.70423191  1.40948977]
#  [-2.70617192 -0.62910305]].	 weights of second layer: [[-1.45671743 -1.52380272]]
#
#
#
#
# Iteration: 987
# Old weights:
# weights of first layer: [[-0.70423191  1.40948977]
#  [-2.70617192 -0.62910305]].	 weights of second layer: [[-1.45671743 -1.52380272]]
# New weights:
# weights of first layer: [[-0.70421678  1.40945694]
#  [-2.70617586 -0.62914899]].	 weights of second layer: [[-1.45666548 -1.52378833]]
#
#
#
#
# Iteration: 988
# Old weights:
# weights of first layer: [[-0.70421678  1.40945694]
#  [-2.70617586 -0.62914899]].	 weights of second layer: [[-1.45666548 -1.52378833]]
# New weights:
# weights of first layer: [[-0.70420165  1.40942413]
#  [-2.70617981 -0.62919492]].	 weights of second layer: [[-1.45661353 -1.52377395]]
#
#
#
#
# Iteration: 989
# Old weights:
# weights of first layer: [[-0.70420165  1.40942413]
#  [-2.70617981 -0.62919492]].	 weights of second layer: [[-1.45661353 -1.52377395]]
# New weights:
# weights of first layer: [[-0.70418651  1.40939132]
#  [-2.70618375 -0.62924084]].	 weights of second layer: [[-1.4565616  -1.52375958]]
#
#
#
#
# Iteration: 990
# Old weights:
# weights of first layer: [[-0.70418651  1.40939132]
#  [-2.70618375 -0.62924084]].	 weights of second layer: [[-1.4565616  -1.52375958]]
# New weights:
# weights of first layer: [[-0.70417137  1.40935851]
#  [-2.7061877  -0.62928676]].	 weights of second layer: [[-1.45650967 -1.52374522]]
#
#
#
#
# Iteration: 991
# Old weights:
# weights of first layer: [[-0.70417137  1.40935851]
#  [-2.7061877  -0.62928676]].	 weights of second layer: [[-1.45650967 -1.52374522]]
# New weights:
# weights of first layer: [[-0.70415622  1.40932572]
#  [-2.70619164 -0.62933268]].	 weights of second layer: [[-1.45645776 -1.52373086]]
#
#
#
#
# Iteration: 992
# Old weights:
# weights of first layer: [[-0.70415622  1.40932572]
#  [-2.70619164 -0.62933268]].	 weights of second layer: [[-1.45645776 -1.52373086]]
# New weights:
# weights of first layer: [[-0.70414108  1.40929293]
#  [-2.70619558 -0.62937859]].	 weights of second layer: [[-1.45640587 -1.52371651]]
#
#
#
#
# Iteration: 993
# Old weights:
# weights of first layer: [[-0.70414108  1.40929293]
#  [-2.70619558 -0.62937859]].	 weights of second layer: [[-1.45640587 -1.52371651]]
# New weights:
# weights of first layer: [[-0.70412593  1.40926015]
#  [-2.70619953 -0.6294245 ]].	 weights of second layer: [[-1.45635398 -1.52370217]]
#
#
#
#
# Iteration: 994
# Old weights:
# weights of first layer: [[-0.70412593  1.40926015]
#  [-2.70619953 -0.6294245 ]].	 weights of second layer: [[-1.45635398 -1.52370217]]
# New weights:
# weights of first layer: [[-0.70411077  1.40922738]
#  [-2.70620347 -0.6294704 ]].	 weights of second layer: [[-1.4563021  -1.52368784]]
#
#
#
#
# Iteration: 995
# Old weights:
# weights of first layer: [[-0.70411077  1.40922738]
#  [-2.70620347 -0.6294704 ]].	 weights of second layer: [[-1.4563021  -1.52368784]]
# New weights:
# weights of first layer: [[-0.70409561  1.40919461]
#  [-2.70620741 -0.62951629]].	 weights of second layer: [[-1.45625024 -1.52367352]]
#
#
#
#
# Iteration: 996
# Old weights:
# weights of first layer: [[-0.70409561  1.40919461]
#  [-2.70620741 -0.62951629]].	 weights of second layer: [[-1.45625024 -1.52367352]]
# New weights:
# weights of first layer: [[-0.70408045  1.40916185]
#  [-2.70621135 -0.62956219]].	 weights of second layer: [[-1.45619839 -1.5236592 ]]
#
#
#
#
# Iteration: 997
# Old weights:
# weights of first layer: [[-0.70408045  1.40916185]
#  [-2.70621135 -0.62956219]].	 weights of second layer: [[-1.45619839 -1.5236592 ]]
# New weights:
# weights of first layer: [[-0.70406529  1.4091291 ]
#  [-2.70621529 -0.62960807]].	 weights of second layer: [[-1.45614655 -1.52364489]]
#
#
#
#
# Iteration: 998
# Old weights:
# weights of first layer: [[-0.70406529  1.4091291 ]
#  [-2.70621529 -0.62960807]].	 weights of second layer: [[-1.45614655 -1.52364489]]
# New weights:
# weights of first layer: [[-0.70405012  1.40909636]
#  [-2.70621922 -0.62965395]].	 weights of second layer: [[-1.45609472 -1.52363059]]
#
#
#
#
# Iteration: 999
# Old weights:
# weights of first layer: [[-0.70405012  1.40909636]
#  [-2.70621922 -0.62965395]].	 weights of second layer: [[-1.45609472 -1.52363059]]
# New weights:
# weights of first layer: [[-0.70403495  1.40906362]
#  [-2.70622316 -0.62969983]].	 weights of second layer: [[-1.45604291 -1.52361629]]
#
#
#
#
# Iteration: 1000
# Old weights:
# weights of first layer: [[-0.70403495  1.40906362]
#  [-2.70622316 -0.62969983]].	 weights of second layer: [[-1.45604291 -1.52361629]]
# New weights:
# weights of first layer: [[-0.70401978  1.40903089]
#  [-2.7062271  -0.6297457 ]].	 weights of second layer: [[-1.4559911 -1.523602 ]]

# %%
def predict(X, W1, W2, b1, b2):
    # First hidden layer
    Z1 = W1.dot(X) + b1
    A1 = sigmoid(Z1)

    # 2nd layer (output layer)
    Z2 = W2.dot(A1) + b2
    A2 = sigmoid(Z2)
    
    y_proba = np.squeeze(A2)
    y_pred = np.around(max(y_proba))
    
    return y_pred

# %%
#Test on unknown dataset
y=predict(np.array([1,1]),W1, W2, b1, b2)

# %%
y
# Out:
# 1.0
